# %%
import matplotlib.pyplot as plt
import numpy as np

pts = np.array([(0.70,0.646,0.781,0.945,1.416,1.487),(10.4,17.51,15.79,13.63,6.44,4.179),(1.8,1.86,1.93,1.29,0.68,0.169)])

x_1 = pts[0,:]
y_1 = pts[1,:]
y_1error = pts[2,:]
print(x_1,y_1,y_1error)

m,b = np.polyfit(x_1,y_1,1)
print(m,b)

correlation_matrix = np.corrcoef(x_1,y_1)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# [0.7   0.646 0.781 0.945 1.416 1.487] [10.4   17.51  15.79  13.63   6.44   4.179] [1.8   1.86  1.93  1.29  0.68  0.169]
# -12.60877922266078 23.88107597589969
# 0.7720612530425296

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_1,y_1)
plt.plot(x_1, m*x_1 + b, label='Best Fit Line (y = -12.6x + 23.9)($R^2$ = 0.772)')
plt.legend()
plt.errorbar(x_1,y_1,y_1error,fmt=' ', color='blue')
plt.title('$Q^2$ Dependence at W=2.2, t=0.08', fontsize=20)
plt.xlabel('$Q^2$ ($GeV^2$)', fontsize=15)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)', fontsize=15)
plt.show()

# %%
x_2 = pts[0,:]**3
y_2 = pts[1,:]
y_2error = pts[2,:]

m,b = np.polyfit(x_2,y_2,1)
print(m,b)

correlation_matrix = np.corrcoef(x_2,y_2)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# -3.4818052771205084 16.002082737452373
# 0.7984539873308774

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_2,y_2)
plt.plot(x_2, m*x_2 + b, label='Best Fit Line (y = -3,48x + 16.00)($R^2$=0.798)')
plt.legend()
plt.errorbar(x_2,y_2,y_2error, fmt=' ', color='blue')
plt.title('$(Q^2)^3$ Dependence at W=2.2, t=0.08', fontsize=20)
plt.xlabel('$(Q^2)^3$ ($(GeV^2)^3$)', fontsize=15)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)', fontsize=15)
plt.show()

# %%
x_4 = pts[0,:]**5
y_4 = np.log(pts[1,:])
y_4error = y_4*(pts[2,:]/pts[1,:])
print(x_4)
print(y_4)
print(y_4error)

print('\n')
x_max = (0.11250261,7.27034203)
x_max = np.array(x_max)
y_max = (y_4[1]-y_4error[1], y_4[5]+y_4error[5])
y_max = np.array(y_max)
print(y_min)
x_min = (0.11250261,7.27034203)
x_min = np.array(x_min)
y_min = (y_4[1]+y_4error[1],y_4[5]-y_4error[5])
y_min = np.array(y_min)
print(y_min)

m,b = np.polyfit(x_4,y_4,1)
print(m,b)
m1,b1 = np.polyfit(x_min,y_min,1)
print(m1,b1)
m2,b2 = np.polyfit(x_max,y_max,1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_4,y_4)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# [0.16807    0.11250261 0.29057294 0.7536315  5.69267338 7.27034203]
# [2.34180581 2.86277215 2.75937683 2.61227325 1.86252854 1.43007198]
# [0.40531254 0.30409801 0.33727659 0.24723643 0.1966645  0.05783254]
#
#
# [2.55867413 1.48790452]
# [3.16687016 1.37223945]
# -0.16443493591012556 2.703040131290435
# -0.25072240448369854 3.1950770833015216
# -0.14959396998785462 2.5755038462477886
# 0.8919392498011756

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_4,y_4)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_4, m*x_4 + b, label='Best Fit Line (y = -0.16x + 2.70)($R^2$=0.892)')
plt.plot(x_min, m1*x_min + b1, dashes=(3,5), label='Minimum Slope (y = -0.25x + 3.20)')
plt.plot(x_max, m2*x_max + b2, dashes=(3,5), label='Maximum Slope (y = -0.15x + 2.58)')
plt.legend()
plt.errorbar(x_4,y_4,y_4error, fmt=' ', color='blue')
plt.title('$(Q^2)^5$ at W=2.2, t=0.08', fontsize =20)
plt.xlabel('$(Q^2)^5$ ($(GeV^2)^5$)', fontsize =15)
plt.ylabel(r'ln$\sigma$ (ln$\frac{nbar}{c}$)', fontsize =15)
plt.show()
