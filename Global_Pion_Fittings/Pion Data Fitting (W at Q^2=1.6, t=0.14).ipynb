# %%
import numpy as np

x = [2.001,2.397,2.213]
x_1 = np.array(x)
print(x_1)
print("\n")
y = [7.152,2.807,4.292]
y_1 = np.array(y)
print(y_1)
# Out:
# [2.001 2.397 2.213]
#
#
# [7.152 2.807 4.292]

# %%
y_1error = [0.356,0.124,0.473]
plt.plot(x_1,y_1,'o')
plt.errorbar(x_1,y_1,y_1error, fmt=' ')
plt.title('W Dependence at $Q^2=1.6$, t=0.14', fontsize =20)
plt.xlabel('W (GeV)')
plt.ylabel('$\sigma$ (nbar/c)')
plt.show()

x_min = [2.001,2.397]
y_min = [6.796,2.937]
x_min = np.array(x_min)
y_min = np.array(y_min)

x_max = [2.001,2.397]
y_max = [7.508,2.673]
x_max = np.array(x_max)
y_max = np.array(y_max)

print(x_min)
print(y_min)
print(x_max)
print(y_max)
# Out:
# [2.001 2.397]
# [6.796 2.937]
# [2.001 2.397]
# [7.508 2.673]

# %%
m,b = np.polyfit(x_1,y_1,1)
m1,b1 = np.polyfit(x_min,y_min,1)
m2,b2 = np.polyfit(x_max,y_max,1)
plt.scatter(x_1,y_1)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_1, m*x_1 + b, label='Best Fit Line (y = -11.036x + 29.069)($R^2$=0.981)')
plt.plot(x_min, m1*x_min + b1, linestyle = '--', dashes=(3,5), label='Min Slope (y = -9.696x + 26.188)')
plt.plot(x_max, m2*x_max + b2, linestyle = '--', dashes=(3,5), label='Max Slope (y = -12.272x + 32.076)')
plt.legend()
plt.errorbar(x_1,y_1,y_1error,x_1error, fmt=' ', color = 'blue')
plt.title('W Dependence at $Q^2$=1.6, t=0.14', fontsize =20)
plt.xlabel('W (GeV)', fontsize =13)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)', fontsize =13)
plt.show()

print(m,b)
print(m1,b1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_1,y_1)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# -11.035668205894366 29.06926750305589
# -9.744949494949484 26.295643939393898
# -12.209595959595942 31.939401515151467
# 0.9805519012570918

# %%
x_2 = ((1/2.001),(1/2.397),(1/2.213))
x_2 = np.array(x_2)
print(x_2)
y_2 = y_1
print(y_2)

x_min = [0.4171,0.4999]
x_min = np.array(x_min)
y_min = [2.931,6.796]
y_min = np.array(y_min)
x_max = [0.4172,0.4997]
x_max = np.array(x_max)
y_max = [2.683,7.508]
y_max = np.array(y_max)
print("\n")
print(x_min)
print(y_min)
print("\n")
print(x_max)
print(y_max)
# Out:
# [0.49975012 0.41718815 0.45187528]
# [7.152 2.807 4.292]
#
#
# [0.4171 0.4999]
# [2.931 6.796]
#
#
# [0.4172 0.4997]
# [2.683 7.508]

# %%
m,b = np.polyfit(x_2,y_2,1)
m1,b1 = np.polyfit(x_min,y_min,1)
m2,b2 = np.polyfit(x_max,y_max,1)

plt.figure(figsize=(8,5))
plt.scatter(x_2,y_2)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_2, m*x_2 + b, label='Line of Best Fit (y= 53.063x - 19.461)($R^2$=0.992)')
plt.plot(x_min, m1*x_min + b1, linestyle = '--', dashes=(3,5), label='Min Slope (y = 46.679x - 16.539)')
plt.plot(x_max, m2*x_max + b2, linestyle = '--', dashes = (3,5), label='Max Slope (y = 58.485x - 21.717)')
plt.legend()
plt.errorbar(x_2,y_2,y_1error, fmt=' ', color = 'blue')
plt.title(r'$\frac{1}{W}$ Dependence at $Q^2=1.6$, t=0.14', fontsize =20)
plt.xlabel(r'$\frac{1}{W}$ ($\frac{1}{GeV}$)', fontsize =15)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)', fontsize =15)
plt.show()

print(m,b)
print(m1,b1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_new,y_new)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# 53.06258264472353 -19.460594203706954
# 46.67874396135271 -16.538704106280225
# 58.48484848484867 -21.716878787878887
# 0.9959478742547588

# %%
x_3 = [1/(2.001**2),1/(2.397**2),1/(2.213**2)]
x_3 = np.array(x_new)
y_3 = y_1
print(x_new)
print(y_new)

print('\n')
x_min = [1/(2.397**2),1/(2.001*2.001)]
x_min = np.array(x_min)
y_min = [2.931,6.796]
y_min = np.array(y_min)

x_max = [1/(2.397*2.397),1/(2.001*2.001)]
x_max = np.array(x_max)
y_max = [2.683,7.508]
y_max = np.array(y_max)

print(x_min)
print(y_min)
print('\n')
print(x_max)
print(y_max)
# Out:
# [0.24975019 0.17404595 0.20419127]
# [7.152 2.807 4.292]
#
#
# [0.17404595 0.24975019]
# [2.931 6.796]
#
#
# [0.17404595 0.24975019]
# [2.683 7.508]

# %%
m,b = np.polyfit(x_new,y_new,1)
m1,b1 = np.polyfit(x_min,y_min,1)
m2,b2 = np.polyfit(x_max,y_max,1)

plt.figure(figsize=(8,5))
plt.scatter(x_new,y_new)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_new, m*x_new + b, label='Best Fit Line (y = 57.828x - 7.354)($R^2=0.996$)')
plt.plot(x_min, m1*x_min + b1, linestyle='--', dashes=(3,5), label='Min Slope (y = 46.679x - 16.539)')
plt.plot(x_max, m2*x_max + b2, linestyle='--', dashes=(3,5), label='Max Slope (y = 58.485x - 21.717)')
plt.legend()
plt.errorbar(x_new,y_new,y_1error, fmt=" ", color='blue')
plt.title(r"Pion $\frac{1}{W^2}$ Dependence at $Q^2=1.6$, t=0.14",fontsize =20)
plt.xlabel(r"$\frac{1}{W^2}$ ($\frac{1}{(GeV)^2}$)", fontsize =15)
plt.ylabel(r"$\sigma$ ($\frac{nbar}{c}$)", fontsize=15)
plt.show()

print(m,b)
print(m1,b1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_new,y_new)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# 57.828007960891235 -7.35475369238664
# 51.05394811112423 -5.954733106990783
# 63.73487700806582 -8.409797475091988
# 0.9959478742547588
