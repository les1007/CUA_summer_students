# %%
import matplotlib.pyplot as plt
import numpy as np

pts = np.array([(0.70,1.939,2.125,1.35,1.455,1.593,1.617),(5.81,3.175,2.768,4.62,7.152,4.292,2.807),(0.9,0.361,0.272,0.21,0.356,0.473,0.124)])
x_1 = pts[0,:]
y_1 = pts[1,:]
y_1error = pts[2,:]
            
print(x_1)
print(y_1)
print(y_1error)

x_min = (pts[0,0],pts[0,2])
x_min = np.array(x_min)
y_min = (pts[1,0]+pts[2,0],pts[1,2]-pts[2,2])
y_min = np.array(y_min)
x_max = (pts[0,0],pts[0,2])
x_max = np.array(x_max)
y_max = (pts[1,0]-pts[2,0],pts[1,2]+pts[2,2])
y_max = np.array(y_max)

print('\n')
m,b = np.polyfit(x_1,y_1,1)
print(m,b)
m1,b1 = np.polyfit(x_min,y_min,1)
print(m1,b1)
m2,b2 = np.polyfit(x_max,y_max,1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_1,y_1)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# [0.7   1.939 2.125 1.35  1.455 1.593 1.617]
# [5.81  3.175 2.768 4.62  7.152 4.292 2.807]
# [0.9   0.361 0.272 0.21  0.356 0.473 0.124]
#
#
# -2.408110536167762 8.083003352764615
# -2.9571929824561414 8.7800350877193
# -1.312280701754386 5.828596491228072
# 0.447421910303939

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_1,y_1)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_1, m*x_1 + b, label='Best Fit (y = -2.41 + 8.08) ($R^2$=0.447)')
plt.plot(x_min, m1*x_min + b1, dashes=(3,5), label='Min Slope (y = -2.96x + 8.78)')
plt.plot(x_max, m2*x_max + b2, dashes=(3,5), label='Max Slope (y = -1.31x + 5.83)')
plt.legend()
plt.errorbar(x_1,y_1,y_1error, fmt=' ')
plt.title('$Q^2$ Dependence at W=2.2, t=0.14', fontsize=20)
plt.xlabel('$Q^2$ ($GeV^2$)', fontsize=15)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)',fontsize=15)
plt.show()

# %%
x_2 = pts[0,:]*pts[0,:]
y_2 = pts[1,:]
print(x_2)
print(y_2)

pts_2 = np.array([(0.49,4.516),(4.91,3.040),(0.49,4.516),(6.81,2.496)])
x_min = pts_2[2,:]
y_min = pts_2[3,:]
x_max = pts_2[0,:]
y_max = pts_2[1,:]

print('\n')
m,b = np.polyfit(x_2,y_2,1)
print(m,b)
m1,b1 = np.polyfit(x_min,y_min,1)
print(m1,b1)
m2,b2 = np.polyfit(x_max,y_max,1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_2,y_2)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# [0.49     3.759721 4.515625 1.8225   2.117025 2.537649 2.614689]
# [5.81  3.175 2.768 4.62  7.152 4.292 2.807]
#
#
# -0.8791052163827191 6.617480797419492
# -1.0715350223546944 7.335052160953799
# -0.46448087431694 5.137595628415301
# 0.48739311807356467

# %%
plt.figure(figsize=(10,6.5))
plt.scatter(x_2,y_2)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_2, m*x_2 + b, label='Best Fit Line (y = -0.879x + 6.618) ($R^2$=0.487)')
plt.plot(x_min, m1*x_min + b1, label='Min Slope (y = -1.072x + 7.335)', dashes=(3,5))
plt.plot(x_max, m2*x_max + b2, label='Max Slope (y = -0.464x + 5.138)', dashes=(3,5))
plt.errorbar(x_2,y_2,y_1error, fmt=' ', color='blue')
plt.legend()
plt.title('$(Q^2)^2$ Dependence at W=2.2, t=0.14', fontsize=20)
plt.xlabel('$(Q^2)^2$ ($(GeV^2)^2$)', fontsize=15)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)',fontsize=15)
plt.show()

# %%
x_3 = pts[0,:]*pts[0,:]*pts[0,:]
y_3 = pts[1,:]

pts_2 = np.array([(0.7**3,2.125**3),(4.91,3.040),(0.7**3,2.125**3),(6.81,2.496)])
x_min = pts_2[2,:]
y_min=pts_2[3,:]
x_max=pts_2[0,:]
y_max=pts_2[1,:]

m,b = np.polyfit(x_3,y_3,1)
m1,b1 = np.polyfit(x_min,y_min,1)
m2,b2 = np.polyfit(x_max,y_max,1)
print(m,b)
print(m1,b1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_3,y_3)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# -0.37382381653010527 6.032492102845318
# -0.46624212856715885 6.969921050098536
# -0.20210310162739617 4.9793213638581975
# 0.4920505789446991

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_3,y_3)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_3, m*x_3 + b, label='Best Fit Line (y = -0.37x + 6.03)($R^2$=0.492)')
plt.plot(x_min, m1*x_min + b1, dashes=(3,5), label='Min Slope (y = -0.47x + 6.97)')
plt.plot(x_max, m2*x_max + b2, dashes=(3,5), label='Max Slope (y = -0.20x + 4.98)')
plt.legend()
plt.errorbar(x_3,y_3,y_1error, fmt=' ', color='blue')
plt.title('$(Q^2)^3$ Dependence at W=2.2, t=0.14', fontsize=20)
plt.xlabel('$(Q^2)^3$ ($(GeV^2)^3$)', fontsize =15)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)', fontsize=15)
plt.show()

# %%
x_4 = pts[0,:]**3
y_4 = np.log(pts[1,:])
y_4error = y_4*(pts[2,:]/pts[1,:])
print(x_4)
print(y_4)
print(y_4error)

x_min = (0.343, 9.59570312)
x_min = np.array(x_min)
y_min = (1.75958057+0.27256842,1.01812504-0.10004697)
y_min = np.array(y_min)
x_max = (0.343, 9.59570312)
x_max = np.array(x_max)
y_max = (1.75958057-0.27256842,1.01812504+0.10004697)
y_max = np.array(y_max)

m,b = np.polyfit(x_4,y_4,1)
m1,b1 = np.polyfit(x_min,y_min,1)
m2,b2 = np.polyfit(x_max,y_max,1)
print(m,b)
print(m1,b1)
print(m2,b2)

correlation_matrix = np.corrcoef(x_4,y_4)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# [0.343      7.29009902 9.59570312 2.460375   3.08027138 4.04247486
#  4.22795211]
# [1.75958057 1.15530763 1.01812504 1.53039471 1.96739204 1.45675282
#  1.0321163 ]
# [0.27256842 0.13135939 0.10004697 0.0695634  0.09792947 0.16054149
#  0.04559402]
# -0.08898199024576568 1.8116655720098473
# -0.12040491362917523 2.073447875374807
# -0.039862960609072254 1.5006851454889116
# 0.5613648796513295

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_4,y_4)
plt.scatter(x_min,y_min)
plt.scatter(x_max,y_max)
plt.plot(x_4, m*x_4 + b, label='Best Fit Line (y = -0.09x + 1.81)($R^2$=0.561)')
plt.plot(x_min, m1*x_min + b1, dashes=(3,5), label='Min Slope (y = -0.12x + 2.07)')
plt.plot(x_max, m2*x_max + b2, dashes=(3,5), label='Max Slope (y = -0.04x + 1.50)')
plt.legend()
plt.errorbar(x_4,y_4,y_4error,fmt=' ', color='blue')
plt.title('$(Q^2)^3$ Dependence at W=2.2, t=0.14', fontsize=20)
plt.xlabel('$(Q^2)^3$ ($(GeV^2)^3$)', fontsize =13)
plt.ylabel(r'ln$\sigma$ (ln$\frac{nbar}{c}$)', fontsize=13)
plt.show()
