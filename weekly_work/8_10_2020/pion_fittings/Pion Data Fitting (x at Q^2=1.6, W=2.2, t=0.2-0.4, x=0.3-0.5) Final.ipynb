# %%
import matplotlib.pyplot as plt
import numpy as np

pts = np.array([(0.320,0.381,0.396,0.426,0.476,0.311,0.323,0.318),(3.35,4.08,1.78,1.58,0.721,3.175,2.768,7.152),(0.41,0.41,0.18,0.19,0.060,0.361,0.272,0.356)])

x = pts[0,:]
y = pts[1,:]
yerror = pts[2,:]

m,b = np.polyfit(x,y,1)
print(m,b)

correlation_matrix = np.corrcoef(x,y)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# -21.99669902074144 11.18978235127599
# 0.4623407361201071

# %%
plt.figure(figsize=(8,5))
plt.scatter(x,y)
plt.plot(x, m*x + b, label='Best Fit Line (y = -21.997x + 11.190)($R^2$=0.462)')
plt.legend()
plt.errorbar(x,y,yerror,fmt=' ')
plt.title('Fig1. x Dependence at $Q^2$=1.6, W=2.2, t=0.2-0.4, x=0.3-0.5', fontsize=20)
plt.xlabel('x', fontsize=15)
plt.ylabel(r'$\sigma$ ($\frac{nbar}{c}$)', fontsize=15)
plt.show()

# %%
x_2 = pts[0,:]**5
y_2 = np.log(pts[1,:])
y_2error = y_2*(pts[2,:]/pts[1,:])

m,b = np.polyfit(x_2,y_2,1)
print(m,b)

correlation_matrix = np.corrcoef(x_2,y_2)
correlation_xy = correlation_matrix[0,1]
r_squared = correlation_xy**2
print(r_squared)
# Out:
# -80.4911390000804 1.629751233549785
# 0.7622269162270738

# %%
plt.figure(figsize=(8,5))
plt.scatter(x_2,y_2)
plt.plot(x_2, m*x_2 + b, label='Best Fit Line (y = -80.491x + 1.630)($R^2$=0.762)')
plt.legend()
plt.errorbar(x_2,y_2,y_2error,fmt=' ')
plt.title('Fig2. $x^5$ Dependence at $Q^2$=1.6, W=2.2, t=0.2-0.4, x=0.3-0.5', fontsize=20)
plt.xlabel('$x^5$', fontsize=15)
plt.ylabel(r'ln$\sigma$ (ln$\frac{nbar}{c}$)', fontsize=15)
plt.show()

# %% [markdown]
# Figure 1 shows the plot of the raw pion data set of x at $Q^2$=1.6, W=2.2, t=0.2-0.4, and x=0.3-0.5. The best fit line of the raw data plot has an $R^2$ value of 0.462. The best fit for this data set can be seen when $x^5$ is plotted against ln$\sigma$ as illustrated in Figure2. The equation of the line of best fit is y = -80.491x + 1.630 and the $R^2$ value for this fit is 0.762. Because this is not a very acceptable $R^2$ value, there could be other fits that may yield better results than this fit.
